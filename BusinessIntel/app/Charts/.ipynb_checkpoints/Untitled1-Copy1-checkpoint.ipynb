# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
file = "correlation.csv"
df = pd.read_csv(file, index_col=0)

# %% [markdown]
# I clean the datasets here

# %%
desc = df["Description"].value_counts()
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"]).dt.date
df.head()
# Out:
#   InvoiceNo InvoiceDate  CustomerID                          Description  \
# 0    536365  2010-12-01     17850.0   WHITE HANGING HEART T-LIGHT HOLDER
# 1    536365  2010-12-01     17850.0                  WHITE METAL LANTERN
# 2    536365  2010-12-01     17850.0       CREAM CUPID HEARTS COAT HANGER
# 3    536365  2010-12-01     17850.0  KNITTED UNION FLAG HOT WATER BOTTLE
# 4    536365  2010-12-01     17850.0       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity  UnitPrice  BroughtPrice  Profit
# 0         6       2.55         2.040   0.510
# 1         6       3.39         2.712   0.678
# 2         8       2.75         2.200   0.550
# 3         6       3.39         2.712   0.678
# 4         6       3.39         2.712   0.678

# %% [markdown]
# # Product should be kept

# %% [markdown]
# ##### We can see here in the bar Chart the items need to be kept and order more quantity and we can answer the question what product most profitable and product to be kept

# %%
plt.figure(figsize=(12,8))
sns.barplot(desc.head(40).index, desc.head(40).values)
plt.xticks(rotation="vertical")
plt.title("Most Item sold from 2010-2011", fontsize=20)
plt.xlabel("Item Description", fontsize=15)
plt.ylabel("Item Quantity")
plt.show()

# %% [markdown]
# # Items sold within a Year

# %%
inv_data = df["InvoiceDate"].value_counts().sort_index()
inv_data.head()
# Out:
# 2010-12-01    3108
# 2010-12-02    2109
# 2010-12-03    2202
# 2010-12-05    2725
# 2010-12-06    3878
# Name: InvoiceDate, dtype: int64

# %% [markdown]
# #### Here at the new chart, we can see the summary items most purchased by  months.

# %%
plt.figure(figsize=(12,8))
inv_data.plot(color="red")
plt.xticks(rotation="vertical", fontsize=15)
plt.title("Summary for item Sold in a Year", fontsize=20)
plt.xlabel("Months", fontsize=15)
plt.ylabel("Item Release Quantity", fontsize=15)
plt.show()

# %% [markdown]
# # Customer who buy more often

# %% [markdown]
# #### Here we can see at the chart below the customer who purchased more using by their Customer ID

# %%
custID = df["CustomerID"].value_counts().reset_index()
custID.columns = ["CustID","Items they buyed"]
custID["CustID"] = custID["CustID"].apply(str)
custIDx = custID.sort_values("Items they buyed", ascending=False).head(40)
custIDx.head()
# Out:
#     CustID  Items they buyed
# 0  17841.0              7983
# 1  14911.0              5903
# 2  14096.0              5128
# 3  12748.0              4642
# 4  14606.0              2782

# %% [markdown]
# #

# %%
plt.figure(figsize=(12,8))
g = sns.barplot(custIDx.index, custIDx["Items they buyed"])
g.set_xticklabels(custIDx["CustID"], rotation="vertical")
plt.title("Customer who buy more often", fontsize=20)
plt.xlabel("Customer ID", fontsize=15)
plt.ylabel("Item Frequency", fontsize=15)
plt.show()

# %% [markdown]
# #

# %% [markdown]
# ##### I Add the Total Amount for the item they purchased "Quantity" x "Unit Price" = "Total Amount", so I can graph the total amount they purchased per Customer

# %%
prod_prof = df
prod_prof["TotalAmount"] = prod_prof["Quantity"]*prod_prof["UnitPrice"]
prod_prof.head()
# Out:
#   InvoiceNo InvoiceDate  CustomerID                          Description  \
# 0    536365  2010-12-01     17850.0   WHITE HANGING HEART T-LIGHT HOLDER
# 1    536365  2010-12-01     17850.0                  WHITE METAL LANTERN
# 2    536365  2010-12-01     17850.0       CREAM CUPID HEARTS COAT HANGER
# 3    536365  2010-12-01     17850.0  KNITTED UNION FLAG HOT WATER BOTTLE
# 4    536365  2010-12-01     17850.0       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity  UnitPrice  BroughtPrice  Profit  TotalAmount
# 0         6       2.55         2.040   0.510        15.30
# 1         6       3.39         2.712   0.678        20.34
# 2         8       2.75         2.200   0.550        22.00
# 3         6       3.39         2.712   0.678        20.34
# 4         6       3.39         2.712   0.678        20.34

# %%
prod_prof["TotalAmount"].sum() # Anually Sale
# Out:
# 9747747.93400317

# %%
total_amount = prod_prof.groupby("InvoiceDate")["TotalAmount","Quantity","UnitPrice"].agg({"TotalAmount":["sum","count"],
                                                                                           "Quantity":["sum","count"],
                                                                                            "UnitPrice":["sum","count"]})
total_amount.head()
# Out:
#             TotalAmount       Quantity       UnitPrice
#                     sum count      sum count       sum count
# InvoiceDate
# 2010-12-01     58635.56  3108    26814  3108  12904.25  3108
# 2010-12-02     46207.28  2109    21023  2109   6815.68  2109
# 2010-12-03     45620.46  2202    14830  2202  11114.09  2202
# 2010-12-05     31383.95  2725    16395  2725   7893.17  2725
# 2010-12-06     53860.18  3878    21419  3878  17678.78  3878

# %% [markdown]
# #

# %% [markdown]
# ### We can put this as a  special occasions  products will be sold more

# %%
monthly_prod = prod_prof[["InvoiceDate","Description"]]
monthly_prod.head()
# Out:
#   InvoiceDate                          Description
# 0  2010-12-01   WHITE HANGING HEART T-LIGHT HOLDER
# 1  2010-12-01                  WHITE METAL LANTERN
# 2  2010-12-01       CREAM CUPID HEARTS COAT HANGER
# 3  2010-12-01  KNITTED UNION FLAG HOT WATER BOTTLE
# 4  2010-12-01       RED WOOLLY HOTTIE WHITE HEART.

# %%
start_date = "2010-10-01" # YYYY-MM-DD
end_date = "2011-10-02" # YYYY-MM-DD

# %%
def monthly_sale(start_date, end_date):
    ta = monthly_prod
    mask = (ta["InvoiceDate"] > np.datetime64(start_date)) & (ta["InvoiceDate"] <= np.datetime64(end_date))
    prod = ta[mask]["Description"].value_counts(ascending=False, dropna=True).head(20)
    plt.figure(figsize=(12,8))
    sns.barplot(prod.index, prod.values)
    plt.xticks(rotation="vertical")
    plt.xlabel("Items Mostly sold", fontsize=20)
    plt.ylabel("Items Frequency", fontsize=20)
    plt.title("Items Sold by this Date Range", fontsize=30)
    plt.show()
    #return prod.index, prod.values  <------ unhash this to get your requested output for X and Y
    
    

monthly_sale(start_date, end_date)

# %% [markdown]
# #

# %% [markdown]
# # Model for Predicting sale

# %%
prod_prof.head()
# Out:
#   InvoiceNo InvoiceDate  CustomerID                          Description  \
# 0    536365  2010-12-01     17850.0   WHITE HANGING HEART T-LIGHT HOLDER
# 1    536365  2010-12-01     17850.0                  WHITE METAL LANTERN
# 2    536365  2010-12-01     17850.0       CREAM CUPID HEARTS COAT HANGER
# 3    536365  2010-12-01     17850.0  KNITTED UNION FLAG HOT WATER BOTTLE
# 4    536365  2010-12-01     17850.0       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity  UnitPrice  BroughtPrice  Profit  TotalAmount
# 0         6       2.55         2.040   0.510        15.30
# 1         6       3.39         2.712   0.678        20.34
# 2         8       2.75         2.200   0.550        22.00
# 3         6       3.39         2.712   0.678        20.34
# 4         6       3.39         2.712   0.678        20.34

# %% [markdown]
# #

# %% [markdown]
# #### i clean the datasets here for our models

# %%
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
total_amount.head()
# Out:
#             TotalAmount       Quantity       UnitPrice
#                     sum count      sum count       sum count
# InvoiceDate
# 2010-12-01     58635.56  3108    26814  3108  12904.25  3108
# 2010-12-02     46207.28  2109    21023  2109   6815.68  2109
# 2010-12-03     45620.46  2202    14830  2202  11114.09  2202
# 2010-12-05     31383.95  2725    16395  2725   7893.17  2725
# 2010-12-06     53860.18  3878    21419  3878  17678.78  3878

# %%
y = total_amount["TotalAmount"]["sum"].values
X = total_amount[["Quantity","UnitPrice"]].values
X
# Out:
# array([[ 26814.  ,   3108.  ,  12904.25,   3108.  ],
#        [ 21023.  ,   2109.  ,   6815.68,   2109.  ],
#        [ 14830.  ,   2202.  ,  11114.09,   2202.  ],
#        ...,
#        [ 39612.  ,   2438.  ,   9049.19,   2438.  ],
#        [ 34460.  ,   4940.  ,  21808.1 ,   4940.  ],
#        [ 12949.  ,   1632.  ,   9226.48,   1632.  ]])

# %% [markdown]
# ### I Split the datasets by 30%

# %%
train_x, test_x, train_y, test_y = train_test_split(X, y, test_size=0.30, random_state=415)  # i split the datasets here by 30%

# %%
'''I am using the SVR Polynomial from the sklearn model, with iteration by 1000 '''
svr_lin = SVR(kernel="poly", C=1e-5, degree=1, max_iter=1000)
svr_lin.fit(train_x, train_y) # i feed the training sets here to our model
yhat = svr_lin.predict(train_x) # and this is the output or a prediction for our training sets
div = len(train_y) # dont mind this
div_len = len(total_amount) # dont mind this

# %%
'''This is plotting section'''
fig, ax = plt.subplots(figsize=(20,8))
a = total_amount.index[0:div] # this is the date ex: '2010-10-1, 2010-10-2, 2010-10-3'
ax.plot(a, train_y, "k", label="Train sets", color="green") # i put on the plot for our expected output, this is the color green
ax.plot(a, yhat, "k--", label="Prediction", color="red") # here is the plot for prediction, this is color red in our plot
ax.legend(loc="upper right", shadow=True, fontsize=20)
plt.xticks(rotation="vertical")
plt.title("Train Prediction", fontsize=30)
plt.xlabel("Sales in a Months", fontsize=20)
plt.ylabel("Sale in a Month", fontsize=20)
plt.show()

# %% [markdown]
# #### We can see here the postive outcome of our model, the sets are not overfit, so lets check the prediction below for test

# %%
test_yhat = svr_lin.predict(test_x)

# %%
fig, ax = plt.subplots(figsize=(20,8))
a = total_amount.index[div:div_len]
ax.plot(a, test_y, "k", color="green", label="Train Test")
ax.plot(a, test_yhat, "k--", color="red", label="Prediction Test")
ax.legend(loc="upper left", shadow=True, fontsize=20)
plt.title("Test Prediction", fontsize=30)
plt.xticks(rotation="vertical")
plt.xlabel("Months Sale", fontsize=20)
plt.ylabel("Sale in Month", fontsize=20)
plt.show()

# %% [markdown]
# #### as we can see in the test sets, our graph for prediction is good, and we have a positive outcome, so we predict the sales by every month and also a year

# %% [markdown]
# #

# %% [markdown]
# #

# %%
test_y
# Out:
# array([ 27233.14,  37067.17,   6175.17,  40334.97,  33486.36,  43464.33,
#         34131.73,  24391.78,  16791.39,   9363.88,  25124.25,  60329.72,
#         56647.66,  34348.75,  23299.14,  20533.54,  35295.58,  46212.21,
#         34902.01,  35752.16,  24152.28,   6878.1 ,  37074.9 ,  13171.82,
#         23898.2 ,  25858.06,  45620.46,  23344.58,  23837.65,  15710.8 ,
#          6964.66,  21980.64,  72132.79,  36003.43,  60793.14,  33240.36,
#         70001.08,  64408.7 ,  19493.32,  41745.07,  16118.  ,  31978.44,
#         21182.64,  20728.14,   6456.44,   9596.23,   8979.98,  26060.43,
#         34337.29,  17240.92,  40807.49,  22458.88,   5977.14,  62307.32,
#         44154.75,  29302.85,  30656.03,  10784.78,  30744.07,  64214.78,
#         47064.14,  75244.43,  45515.75,  20660.03,  16823.86,  21794.94,
#         54228.37,  24730.81,  11922.24,  26623.2 ,  11796.31,  26361.87,
#          3457.11,  20372.93,   6134.57,  13427.54,  22730.01,  18567.77,
#         33493.4 ,  48080.28,  28433.22,  43834.55,  53225.67,  25520.35,
#         40211.93,  30739.55,  17279.35,  35379.34,  16751.  ,  70531.47,
#         49392.22,  12483.86])

# %% [markdown]
# # Correlation item with other items

# %%
prod_prof.head()
# Out:
#   InvoiceNo InvoiceDate  CustomerID                          Description  \
# 0    536365  2010-12-01     17850.0   WHITE HANGING HEART T-LIGHT HOLDER
# 1    536365  2010-12-01     17850.0                  WHITE METAL LANTERN
# 2    536365  2010-12-01     17850.0       CREAM CUPID HEARTS COAT HANGER
# 3    536365  2010-12-01     17850.0  KNITTED UNION FLAG HOT WATER BOTTLE
# 4    536365  2010-12-01     17850.0       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity  UnitPrice  BroughtPrice  Profit  TotalAmount
# 0         6       2.55         2.040   0.510        15.30
# 1         6       3.39         2.712   0.678        20.34
# 2         8       2.75         2.200   0.550        22.00
# 3         6       3.39         2.712   0.678        20.34
# 4         6       3.39         2.712   0.678        20.34

# %%
corr = pd.read_csv("correlation.csv", index_col=0)
corr.head()
# Out:
#          WHITE HANGING HEART T-LIGHT HOLDER  REGENCY CAKESTAND 3 TIER  \
# 17841.0                                 1.0                       1.0
# 14911.0                                 1.0                       1.0
# 14096.0                                 1.0                       1.0
# 12748.0                                 1.0                       1.0
# 14606.0                                 1.0                       1.0
#
#          JUMBO BAG RED RETROSPOT  PARTY BUNTING  LUNCH BAG RED RETROSPOT  \
# 17841.0                      1.0            1.0                      1.0
# 14911.0                      1.0            1.0                      1.0
# 14096.0                      1.0            1.0                      1.0
# 12748.0                      1.0            1.0                      1.0
# 14606.0                      1.0            1.0                      1.0
#
#          ASSORTED COLOUR BIRD ORNAMENT  SET OF 3 CAKE TINS PANTRY DESIGN   \
# 17841.0                            0.0                                1.0
# 14911.0                            1.0                                1.0
# 14096.0                            0.0                                1.0
# 12748.0                            1.0                                1.0
# 14606.0                            1.0                                0.0
#
#          PACK OF 72 RETROSPOT CAKE CASES  LUNCH BAG  BLACK SKULL.  \
# 17841.0                              1.0                      1.0
# 14911.0                              1.0                      1.0
# 14096.0                              1.0                      0.0
# 12748.0                              1.0                      1.0
# 14606.0                              1.0                      1.0
#
#          NATURAL SLATE HEART CHALKBOARD       ...        \
# 17841.0                              1.0      ...
# 14911.0                              1.0      ...
# 14096.0                              1.0      ...
# 12748.0                              1.0      ...
# 14606.0                              1.0      ...
#
#          add stock to allocate online orders  TEA TIME CAKE STAND IN GIFT BOX  \
# 17841.0                                  0.0                              0.0
# 14911.0                                  0.0                              0.0
# 14096.0                                  0.0                              0.0
# 12748.0                                  0.0                              0.0
# 14606.0                                  0.0                              0.0
#
#          PURPLE CHUNKY GLASS+BEAD NECKLACE  \
# 17841.0                                0.0
# 14911.0                                0.0
# 14096.0                                0.0
# 12748.0                                0.0
# 14606.0                                0.0
#
#          rcvd be air temp fix for dotcom sit  Damages/samples  check?  \
# 17841.0                                  0.0              0.0     0.0
# 14911.0                                  0.0              0.0     0.0
# 14096.0                                  0.0              0.0     0.0
# 12748.0                                  0.0              0.0     0.0
# 14606.0                                  0.0              0.0     0.0
#
#          FLOWER FAIRY 5 SUMMER DRAW LINERS  FIRE POLISHED GLASS NECKL GOLD  \
# 17841.0                                0.0                             0.0
# 14911.0                                0.0                             0.0
# 14096.0                                0.0                             0.0
# 12748.0                                0.0                             0.0
# 14606.0                                0.0                             0.0
#
#          WHITE ANEMONE ARTIFICIAL FLOWER  Unnamed: 4224
# 17841.0                              0.0            NaN
# 14911.0                              0.0            NaN
# 14096.0                              0.0            NaN
# 12748.0                              0.0            NaN
# 14606.0                              0.0            NaN
#
# [5 rows x 4224 columns]

# %% [markdown]
# as we can see above, customer ID brough some items

# %%
cor_ = corr.corr()

# %%
corr.columns
# Out:
# Index(['WHITE HANGING HEART T-LIGHT HOLDER', 'REGENCY CAKESTAND 3 TIER',
#        'JUMBO BAG RED RETROSPOT', 'PARTY BUNTING', 'LUNCH BAG RED RETROSPOT',
#        'ASSORTED COLOUR BIRD ORNAMENT', 'SET OF 3 CAKE TINS PANTRY DESIGN ',
#        'PACK OF 72 RETROSPOT CAKE CASES', 'LUNCH BAG  BLACK SKULL.',
#        'NATURAL SLATE HEART CHALKBOARD ',
#        ...
#        'add stock to allocate online orders',
#        'TEA TIME CAKE STAND IN GIFT BOX', 'PURPLE CHUNKY GLASS+BEAD NECKLACE',
#        'rcvd be air temp fix for dotcom sit', 'Damages/samples', 'check?',
#        'FLOWER FAIRY 5 SUMMER DRAW LINERS', 'FIRE POLISHED GLASS NECKL GOLD',
#        'WHITE ANEMONE ARTIFICIAL FLOWER', 'Unnamed: 4224'],
#       dtype='object', length=4224)

# %%
def corr_items(item):
    list_item = cor_[item].sort_values(ascending=False).head(10)
    x=list_item.index
    y=list_item.values
    
    plt.figure(figsize=(12,8))
    
    sns.barplot(x,y)
    
    plt.title("Correlated Items", fontsize=30)
    plt.xlabel("Items", fontsize=20)
    plt.ylabel("Percentage of correlate", fontsize=20)
    plt.xticks(rotation="vertical")
    plt.show()
    return (x,y)

item = "FIRE POLISHED GLASS NECKL GOLD"
X,Y=corr_items(item)
print(X)
print(Y)
# Out:
# /home/asanka/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)
# Index(['FIRE POLISHED GLASS NECKL GOLD', 'FRESHWATER PEARL BRACELET GOLD',
#        'PEARL & SHELL 42"NECKL. GREEN', 'AMBER FINE BEAD NECKLACE W TASSEL',
#        'PALE PINK/AMETHYST STONE NECKLACE', 'MOP PENDANT SHELL NECKLACE',
#        'FIRE POLISHED GLASS NECKL BRONZE', 'TEAL/FUSCHIA COL BEAD NECKLACE',
#        'PINK FLOCK GLASS CANDLEHOLDER', 'GOLD M.O.P ORBIT DROP EARRINGS'],
#       dtype='object')
# [ 1.          1.          1.          0.70702589  0.70702589  0.57721817
#   0.57721817  0.57721817  0.44700892  0.44700892]

# %% [markdown]
# As per the graph above, if we it can give the correlation items

# %%
new_df = pd.DataFrame(df, copy=True)
# Out:
#   InvoiceNo InvoiceDate  CustomerID                          Description  \
# 0    536365  2010-12-01     17850.0   WHITE HANGING HEART T-LIGHT HOLDER
# 1    536365  2010-12-01     17850.0                  WHITE METAL LANTERN
# 2    536365  2010-12-01     17850.0       CREAM CUPID HEARTS COAT HANGER
# 3    536365  2010-12-01     17850.0  KNITTED UNION FLAG HOT WATER BOTTLE
# 4    536365  2010-12-01     17850.0       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity  UnitPrice  BroughtPrice  Profit  TotalAmount
# 0         6       2.55         2.040   0.510        15.30
# 1         6       3.39         2.712   0.678        20.34
# 2         8       2.75         2.200   0.550        22.00
# 3         6       3.39         2.712   0.678        20.34
# 4         6       3.39         2.712   0.678        20.34

# %%
qty_pred = new_df.groupby('InvoiceDate').agg({"Quantity":["sum","count"]})
qty_pred.reset_index().head()
# Out:
#   InvoiceDate Quantity
#                    sum count
# 0  2010-12-01    26814  3108
# 1  2010-12-02    21023  2109
# 2  2010-12-03    14830  2202
# 3  2010-12-05    16395  2725
# 4  2010-12-06    21419  3878

# %%
X = qty_pred.reset_index()["Quantity"]["count"].reset_index().values
Y = qty_pred.reset_index()["Quantity"]["sum"].values

# %%
qty_pred
# Out:
#             Quantity
#                  sum count
# InvoiceDate
# 2010-12-01     26814  3108
# 2010-12-02     21023  2109
# 2010-12-03     14830  2202
# 2010-12-05     16395  2725
# 2010-12-06     21419  3878
# 2010-12-07     24995  2963
# 2010-12-08     22741  2647
# 2010-12-09     18431  2891
# 2010-12-10     20297  2758
# 2010-12-12     10565  1451
# 2010-12-13     17623  2283
# 2010-12-14     20098  2087
# 2010-12-15     18229  1349
# 2010-12-16     29632  1790
# 2010-12-17     16069  3115
# 2010-12-19      3795   522
# 2010-12-20     14965  1763
# 2010-12-21     15467  1586
# 2010-12-22      3192   291
# 2010-12-23      5648   963
# 2011-01-04      7939  1184
# 2011-01-05     18435  1743
# 2011-01-06     22461  1832
# 2011-01-07     16475  1794
# 2011-01-09      8181  1117
# 2011-01-10      9014  1976
# 2011-01-11     29093  1454
# 2011-01-12     10133  1809
# 2011-01-13     10114  1445
# 2011-01-14     23091  1510
# ...              ...   ...
# 2011-11-06     23295  3437
# 2011-11-07     27689  2099
# 2011-11-08     26124  4070
# 2011-11-09     36238  2716
# 2011-11-10     38077  3275
# 2011-11-11     28513  4089
# 2011-11-13     20356  3018
# 2011-11-14     45959  3597
# 2011-11-15     30221  3445
# 2011-11-16     29353  4195
# 2011-11-17     30779  3621
# 2011-11-18     23535  2920
# 2011-11-20     19369  3334
# 2011-11-21     24004  2930
# 2011-11-22     35284  3967
# 2011-11-23     37350  3619
# 2011-11-24     23743  3766
# 2011-11-25     31026  3125
# 2011-11-27     11161  2543
# 2011-11-28     28647  3330
# 2011-11-29     30511  4313
# 2011-11-30     26482  3454
# 2011-12-01     26819  2901
# 2011-12-02     26952  2880
# 2011-12-04     12396  2038
# 2011-12-05     44119  5331
# 2011-12-06     29026  3365
# 2011-12-07     39612  2438
# 2011-12-08     34460  4940
# 2011-12-09     12949  1632
#
# [305 rows x 2 columns]

# %%
# Out:
# (244,)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-211-bd104208a13b> in <module>()
#       1 from sklearn.metrics import accuracy_score
# ----> 2 accuracy_score(yhat,train_y, normalize=False)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     if y_type.startswith('multilabel'):
#     178         differing_labels = count_nonzero(y_true - y_pred, axis=1)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      79     if len(y_type) > 1:
#      80         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 81                          "and {1} targets".format(type_true, type_pred))
#      82
#      83     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of continuous and multiclass targets
