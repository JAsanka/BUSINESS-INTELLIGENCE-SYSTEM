# %%
import sklearn as sk
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from os import listdir

# %%
#list of the csv file

#path = "G:\\PROJECTS\\BUSINESS-INTELLIGENCE-SYSTEM_1\\datasets_2\\" #path of the CSV file
path = "C:\\Users\\Daryo\\Desktop\\businessIntel\\datasets_from_kaggle\\" #path of the CSV file

files_csv = listdir(path)
files_csv
# Out:
# ['aisles.csv',
#  'departments.csv',
#  'orders.csv',
#  'order_products__prior.csv',
#  'products.csv',
#  'sample_submission.csv']

# %%
aisles = pd.read_csv(path+files_csv[0])
aisles.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
aisles.shape
# Out:
# (134, 2)

# %%
departments = pd.read_csv(path+files_csv[1])
departments.head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
departments.shape
# Out:
# (21, 2)

# %%
orders = pd.read_csv(path+files_csv[2])
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
days = orders["days_since_prior_order"].value_counts().sort_index()

# %%
plt.figure(figsize=(12,8))
sns.barplot(days.index, days.values)
plt.xticks(rotation="vertical")
plt.title("Products ordered per Days", fontsize=20)
plt.xlabel("Days", fontsize=15)
plt.ylabel("Ordered frequency", fontsize=15)
plt.show()
# Out:
# C:\Users\Daryo\Anaconda3\lib\site-packages\seaborn\categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
per_hour = orders["order_hour_of_day"].value_counts()
per_hour.index = per_hour.index + 1
per_hour = per_hour[per_hour.index.sort_values()]

# %%
plt.figure(figsize=(12,8))
sns.barplot(per_hour.index, per_hour.values, color="red")
plt.title("Summary sold per Hour", fontsize=20)
plt.xlabel("Hours", fontsize=15)
plt.ylabel("Order Frequency", fontsize=15)
plt.show()
# Out:
# C:\Users\Daryo\Anaconda3\lib\site-packages\seaborn\categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
users_id = orders["user_id"].value_counts()
user = users_id.value_counts()
user = user[np.arange(100)+1]
# Out:
# C:\Users\Daryo\Anaconda3\lib\site-packages\pandas\core\series.py:696: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self.loc[key]

# %%
plt.figure(figsize=(12,8))
sns.barplot(user.index, user.values)
plt.xticks(rotation="vertical")
plt.xlabel("Customer ID", fontsize=15)
plt.ylabel("Quantity of Items", fontsize=15)
plt.title("Customer purchased most often", fontsize=20)
plt.show()

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
one_week = orders["order_dow"].value_counts()
one_week.index = one_week.index + 1
one_week = one_week[one_week.index.sort_values()]

# %%
plt.figure(figsize=(12,8))
sns.barplot(one_week.index, one_week.values)
plt.xticks(rotation="vertical")
plt.xlabel("Days in a Week", fontsize=15)
plt.ylabel("Item Quantity", fontsize=15)
plt.title("Items sold in a week", fontsize=20)
plt.show()

# %%
order_products__prior = pd.read_csv(path+files_csv[3])
order_products__prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
proir_order = order_products__prior["product_id"].value_counts().sort_values(ascending=False)

# %%
proir_order = proir_order[proir_order.index.sort_values(ascending=True)]
proir_order.head()
# Out:
# 1    1852
# 2      90
# 3     277
# 4     329
# 5      15
# Name: product_id, dtype: int64

# %%
products = pd.read_csv(path+files_csv[4])
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
products.index = np.arange(1,len(products.index)+1)
products["Quantity stock"] = proir_order
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 1           1                         Chocolate Sandwich Cookies        61
# 2           2                                   All-Seasons Salt       104
# 3           3               Robust Golden Unsweetened Oolong Tea        94
# 4           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 5           5                          Green Chile Anytime Sauce         5
#
#    department_id  Quantity stock
# 1             19          1852.0
# 2             13            90.0
# 3              7           277.0
# 4              1           329.0
# 5             13            15.0

# %%
products = products.sort_values("Quantity stock", ascending=False)
products.head(10)
# Out:
#        product_id            product_name  aisle_id  department_id  \
# 24852       24852                  Banana        24              4
# 13176       13176  Bag of Organic Bananas        24              4
# 21137       21137    Organic Strawberries        24              4
# 21903       21903    Organic Baby Spinach       123              4
# 47209       47209    Organic Hass Avocado        24              4
# 47766       47766         Organic Avocado        24              4
# 47626       47626             Large Lemon        24              4
# 16797       16797            Strawberries        24              4
# 26209       26209                   Limes        24              4
# 27845       27845      Organic Whole Milk        84             16
#
#        Quantity stock
# 24852        472565.0
# 13176        379450.0
# 21137        264683.0
# 21903        241921.0
# 47209        213584.0
# 47766        176815.0
# 47626        152657.0
# 16797        142951.0
# ...

# %%
plt.figure(figsize=(12,8))
sns.barplot(products["product_name"].head(40), products["Quantity stock"].head(40))
plt.xticks(rotation="vertical")
plt.xlabel("List of Products", fontsize=15)
plt.ylabel("Quantity stocks", fontsize=15)
plt.title("Quantity per Stocks", fontsize=20)
plt.show()
# Out:
# C:\Users\Daryo\Anaconda3\lib\site-packages\seaborn\categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
aisles.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
aisles.shape
# Out:
# (134, 2)

# %%
departments.head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
departments.shape
# Out:
# (21, 2)

# %%
products.head()
# Out:
#        product_id            product_name  aisle_id  department_id  \
# 24852       24852                  Banana        24              4
# 13176       13176  Bag of Organic Bananas        24              4
# 21137       21137    Organic Strawberries        24              4
# 21903       21903    Organic Baby Spinach       123              4
# 47209       47209    Organic Hass Avocado        24              4
#
#        Quantity stock
# 24852        472565.0
# 13176        379450.0
# 21137        264683.0
# 21903        241921.0
# 47209        213584.0

# %%
aisle_id = products["aisle_id"].value_counts()
aisle_id.sort_index().head()
# Out:
# 1    146
# 2    271
# 3    832
# 4    543
# 5    409
# Name: aisle_id, dtype: int64

# %%
aisle_pct = aisles
aisle_pct.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
aisle_pct.index = np.arange(1,len(aisle_pct)+1)
aisle_pct["aisle stocks"] = aisle_id.sort_index()
aisle_pct = aisle_pct.sort_values("aisle stocks", ascending=False)
aisle_pct.head()
# Out:
#      aisle_id                 aisle  aisle stocks
# 100       100               missing          1258
# 45         45       candy chocolate          1246
# 37         37         ice cream ice          1091
# 47         47  vitamins supplements          1038
# 120       120                yogurt          1026

# %%
plt.figure(figsize=(12,8))
sns.barplot(aisle_pct["aisle"], aisle_pct["aisle stocks"])
plt.xticks(rotation="vertical")
plt.xlabel("List of the Products", fontsize=20)
plt.ylabel("Available Stocks", fontsize=20)
plt.title("Stocks on Aisle", fontsize=20)
plt.show()
# Out:
# C:\Users\Daryo\Anaconda3\lib\site-packages\seaborn\categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
departments.head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
products.head()
# Out:
#        product_id            product_name  aisle_id  department_id  \
# 24852       24852                  Banana        24              4
# 13176       13176  Bag of Organic Bananas        24              4
# 21137       21137    Organic Strawberries        24              4
# 21903       21903    Organic Baby Spinach       123              4
# 47209       47209    Organic Hass Avocado        24              4
#
#        Quantity stock
# 24852        472565.0
# 13176        379450.0
# 21137        264683.0
# 21903        241921.0
# 47209        213584.0

# %%
dept = products
dept_stocks = dept["department_id"].value_counts().sort_index()
dept_stocks.head(10)
# Out:
# 1     4007
# 2      548
# 3     1516
# 4     1684
# 5     1054
# 6     1139
# 7     4365
# 8      972
# 9     1858
# 10      38
# Name: department_id, dtype: int64

# %%
dept_stk = departments
dept_stk.index = np.arange(1, len(dept_stk)+1)
dept_stk["dept stocks"] = dept_stocks
dept_stk = dept_stk.sort_values("dept stocks")
dept_stk.head()
# Out:
#     department_id    department  dept stocks
# 10             10          bulk           38
# 2               2         other          548
# 12             12  meat seafood          907
# 8               8          pets          972
# 5               5       alcohol         1054

# %%
plt.figure(figsize=(12,8))
temp = dept_stk.index
size = np.array(dept_stk["dept stocks"]/dept_stk["dept stocks"].sum())*100
labels = dept_stk["department"]
plt.pie(size, labels=labels, autopct="%1.1f%%", startangle=200)
plt.title("Stocks Distribution", fontsize=20)
plt.show()
